# %%
import joblib
import numpy as np
import pandas as pd
from datetime import datetime
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping

# %store -r export_df
df = export_df

# %store -r export_df_long
df_long = export_df_long

# ----------------------------
# Prepare Data
# ----------------------------
x = df.drop(columns=['activity'])
y = df['activity']

x_long = df_long.drop(columns=['activity'])
y_long = df_long['activity']

# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
y_long_encoded = label_encoder.fit_transform(y_long)

# Split data
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.1, random_state=42, shuffle=False
)

x_long_test = x_long[-100:]
y_long_test = y_long[-100:]
x_long_train = x_long[:-100]
y_long_train = y_long[:-100]

# Scale features
scaler_tabular = StandardScaler()
x_train_scaled = scaler_tabular.fit_transform(x_train)
x_test_scaled = scaler_tabular.transform(x_test)

scaler_long = StandardScaler()
x_long_train_scaled = scaler_long.fit_transform(x_long_train)
x_long_test_scaled = scaler_long.transform(x_long_test)

# Encode labels numerically
y_train_encoded = label_encoder.transform(y_train)
y_test_encoded = label_encoder.transform(y_test)
y_long_train_encoded = label_encoder.transform(y_long_train)
y_long_test_encoded = label_encoder.transform(y_long_test)

# ----------------------------
# Random Forest
# ----------------------------
forest_model = RandomForestClassifier(
    n_estimators=500,
    random_state=42,
    class_weight='balanced'  # helps with imbalanced classes
)
forest_model.fit(x_train_scaled, y_train_encoded)

# ----------------------------
# XGBoost
# ----------------------------
xgb_model = xgb.XGBClassifier(
    objective="multi:softprob",
    num_class=len(label_encoder.classes_),
    n_estimators=500,
    max_depth=8,
    learning_rate=0.15,
    gamma=1,
    reg_alpha=0.1,
    reg_lambda=1,
    subsample=0.8,
    colsample_bytree=0.8,
    eval_metric='mlogloss',
    use_label_encoder=False,
    random_state=42
)
xgb_model.fit(
    x_train_scaled,
    y_train_encoded,
    eval_set=[(x_test_scaled, y_test_encoded)],
    verbose=True
)


# ----------------------------
# Neural Network
# ----------------------------
neural_model = Sequential([
    Input(shape=(x_long_train_scaled.shape[1],)),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dense(len(label_encoder.classes_), activation='softmax')
])

neural_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

neural_model.fit(
    x_long_train_scaled,
    y_long_train_encoded,
    epochs=50,
    batch_size=32,
    validation_split=0.1,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# [0]	validation_0-mlogloss:0.65681
# [1]	validation_0-mlogloss:0.63233
# [2]	validation_0-mlogloss:0.62382
# [3]	validation_0-mlogloss:0.60939
# [4]	validation_0-mlogloss:0.59661
# [5]	validation_0-mlogloss:0.58901
# [6]	validation_0-mlogloss:0.58138
# [7]	validation_0-mlogloss:0.57582
# [8]	validation_0-mlogloss:0.57375
# [9]	validation_0-mlogloss:0.57317
# [10]	validation_0-mlogloss:0.57023
# [11]	validation_0-mlogloss:0.56882
# [12]	validation_0-mlogloss:0.57380
# [13]	validation_0-mlogloss:0.57277
# [14]	validation_0-mlogloss:0.57298
# [15]	validation_0-mlogloss:0.57104
# [16]	validation_0-mlogloss:0.57376
# [17]	validation_0-mlogloss:0.57326
# [18]	validation_0-mlogloss:0.57449
# [19]	validation_0-mlogloss:0.57369
# [20]	validation_0-mlogloss:0.57253
# [21]	validation_0-mlogloss:0.57432
# [22]	validation_0-mlogloss:0.57319
# [23]	validation_0-mlogloss:0.57353
# [24]	validation_0-mlogloss:0.57652
# [25]	validation_0-mlogloss:0.57736
# [26]	validation_0-mlogloss:0.57814
# [27]	validation_0-mlogloss:0.57804
# [28]	validation_0-mlogloss:0.57785
# [29]	validation_0-mlogloss:0.57833
# [30]	validation_0-mlogloss:0.57901
# [31]	validation_0-mlogloss:0.57901
# [32]	validation_0-mlogloss:0.57913
# [33]	validation_0-mlogloss:0.57971
# [34]	validation_0-mlogloss:0.57970
# [35]	validation_0-mlogloss:0.57993
# [36]	validation_0-mlogloss:0.58098
# [37]	validation_0-mlogloss:0.58098
# [38]	validation_0-mlogloss:0.58067
# [39]	validation_0-mlogloss:0.58068
# [40]	validation_0-mlogloss:0.58168
# [41]	validation_0-mlogloss:0.58168
# [42]	validation_0-mlogloss:0.58167
# [43]	validation_0-mlogloss:0.58247
# [44]	validation_0-mlogloss:0.58232
# [45]	validation_0-mlogloss:0.58272
# [46]	validation_0-mlogloss:0.58263
# [47]	validation_0-mlogloss:0.58266
# [48]	validation_0-mlogloss:0.58373
# [49]	validation_0-mlogloss:0.58360
# [50]	validation_0-mlogloss:0.58358
# [51]	validation_0-mlogloss:0.58303
# C:\Users\borja\PycharmProjects\bitcoin-predictor\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [12:50:44] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [52]	validation_0-mlogloss:0.58303
# [53]	validation_0-mlogloss:0.58342
# [54]	validation_0-mlogloss:0.58456
# [55]	validation_0-mlogloss:0.58463
# [56]	validation_0-mlogloss:0.58462
# [57]	validation_0-mlogloss:0.58461
# [58]	validation_0-mlogloss:0.58462
# [59]	validation_0-mlogloss:0.58463
# [60]	validation_0-mlogloss:0.58462
# [61]	validation_0-mlogloss:0.58708
# [62]	validation_0-mlogloss:0.58712
# [63]	validation_0-mlogloss:0.58713
# [64]	validation_0-mlogloss:0.58722
# [65]	validation_0-mlogloss:0.58726
# [66]	validation_0-mlogloss:0.58706
# [67]	validation_0-mlogloss:0.58619
# [68]	validation_0-mlogloss:0.58621
# [69]	validation_0-mlogloss:0.58619
# [70]	validation_0-mlogloss:0.58648
# [71]	validation_0-mlogloss:0.58576
# [72]	validation_0-mlogloss:0.58575
# [73]	validation_0-mlogloss:0.58592
# [74]	validation_0-mlogloss:0.58592
# [75]	validation_0-mlogloss:0.58558
# [76]	validation_0-mlogloss:0.58492
# [77]	validation_0-mlogloss:0.58490
# [78]	validation_0-mlogloss:0.58487
# [79]	validation_0-mlogloss:0.58489
# [80]	validation_0-mlogloss:0.58474
# [81]	validation_0-mlogloss:0.58476
# [82]	validation_0-mlogloss:0.58573
# [83]	validation_0-mlogloss:0.58568
# [84]	validation_0-mlogloss:0.58572
# [85]	validation_0-mlogloss:0.58567
# [86]	validation_0-mlogloss:0.58567
# [87]	validation_0-mlogloss:0.58567
# [88]	validation_0-mlogloss:0.58642
# [89]	validation_0-mlogloss:0.58598
# [90]	validation_0-mlogloss:0.58595
# [91]	validation_0-mlogloss:0.58641
# [92]	validation_0-mlogloss:0.58647
# [93]	validation_0-mlogloss:0.58649
# [94]	validation_0-mlogloss:0.58700
# [95]	validation_0-mlogloss:0.58693
# [96]	validation_0-mlogloss:0.58696
# [97]	validation_0-mlogloss:0.58699
# [98]	validation_0-mlogloss:0.58700
# [99]	validation_0-mlogloss:0.58683
# [100]	validation_0-mlogloss:0.58673
# [101]	validation_0-mlogloss:0.58686
# [102]	validation_0-mlogloss:0.58689
# [103]	validation_0-mlogloss:0.58694
# [104]	validation_0-mlogloss:0.58621
# [105]	validation_0-mlogloss:0.58619
# [106]	validation_0-mlogloss:0.58619
# [107]	validation_0-mlogloss:0.58619
# [108]	validation_0-mlogloss:0.58619
# [109]	validation_0-mlogloss:0.58621
# [110]	validation_0-mlogloss:0.58477
# [111]	validation_0-mlogloss:0.58483
# [112]	validation_0-mlogloss:0.58569
# [113]	validation_0-mlogloss:0.58587
# [114]	validation_0-mlogloss:0.58685
# [115]	validation_0-mlogloss:0.58686
# [116]	validation_0-mlogloss:0.58706
# [117]	validation_0-mlogloss:0.58708
# [118]	validation_0-mlogloss:0.58755
# [119]	validation_0-mlogloss:0.58753
# [120]	validation_0-mlogloss:0.58755
# [121]	validation_0-mlogloss:0.58752
# [122]	validation_0-mlogloss:0.58748
# [123]	validation_0-mlogloss:0.58750
# [124]	validation_0-mlogloss:0.58744
# [125]	validation_0-mlogloss:0.58701
# [126]	validation_0-mlogloss:0.58705
# [127]	validation_0-mlogloss:0.58704
# [128]	validation_0-mlogloss:0.58729
# [129]	validation_0-mlogloss:0.58734
# [130]	validation_0-mlogloss:0.58755
# [131]	validation_0-mlogloss:0.58748
# [132]	validation_0-mlogloss:0.58750
# [133]	validation_0-mlogloss:0.58751
# [134]	validation_0-mlogloss:0.58757
# [135]	validation_0-mlogloss:0.58763
# [136]	validation_0-mlogloss:0.58786
# [137]	validation_0-mlogloss:0.58789
# [138]	validation_0-mlogloss:0.58797
# [139]	validation_0-mlogloss:0.58794
# [140]	validation_0-mlogloss:0.58783
# [141]	validation_0-mlogloss:0.58779
# [142]	validation_0-mlogloss:0.58775
# [143]	validation_0-mlogloss:0.58779
# [144]	validation_0-mlogloss:0.58894
# [145]	validation_0-mlogloss:0.58889
# [146]	validation_0-mlogloss:0.58884
# [147]	validation_0-mlogloss:0.58934
# [148]	validation_0-mlogloss:0.58992
# [149]	validation_0-mlogloss:0.58991
# [150]	validation_0-mlogloss:0.58992
# [151]	validation_0-mlogloss:0.58988
# [152]	validation_0-mlogloss:0.58967
# [153]	validation_0-mlogloss:0.58972
# [154]	validation_0-mlogloss:0.58934
# [155]	validation_0-mlogloss:0.58930
# [156]	validation_0-mlogloss:0.58931
# [157]	validation_0-mlogloss:0.58902
# [158]	validation_0-mlogloss:0.58908
# [159]	validation_0-mlogloss:0.58906
# [160]	validation_0-mlogloss:0.58903
# [161]	validation_0-mlogloss:0.58942
# [162]	validation_0-mlogloss:0.58938
# [163]	validation_0-mlogloss:0.58944
# [164]	validation_0-mlogloss:0.58947
# [165]	validation_0-mlogloss:0.58946
# [166]	validation_0-mlogloss:0.58948
# [167]	validation_0-mlogloss:0.58947
# [168]	validation_0-mlogloss:0.58945
# [169]	validation_0-mlogloss:0.58937
# [170]	validation_0-mlogloss:0.58940
# [171]	validation_0-mlogloss:0.58936
# [172]	validation_0-mlogloss:0.59008
# [173]	validation_0-mlogloss:0.59006
# [174]	validation_0-mlogloss:0.59009
# [175]	validation_0-mlogloss:0.59013
# [176]	validation_0-mlogloss:0.59011
# [177]	validation_0-mlogloss:0.59007
# [178]	validation_0-mlogloss:0.59011
# [179]	validation_0-mlogloss:0.59015
# [180]	validation_0-mlogloss:0.59014
# [181]	validation_0-mlogloss:0.59008
# [182]	validation_0-mlogloss:0.59019
# [183]	validation_0-mlogloss:0.59016
# [184]	validation_0-mlogloss:0.59006
# [185]	validation_0-mlogloss:0.59006
# [186]	validation_0-mlogloss:0.59006
# [187]	validation_0-mlogloss:0.59005
# [188]	validation_0-mlogloss:0.59000
# [189]	validation_0-mlogloss:0.59021
# [190]	validation_0-mlogloss:0.59018
# [191]	validation_0-mlogloss:0.59012
# [192]	validation_0-mlogloss:0.59010
# [193]	validation_0-mlogloss:0.58915
# [194]	validation_0-mlogloss:0.58920
# [195]	validation_0-mlogloss:0.58916
# [196]	validation_0-mlogloss:0.58912
# [197]	validation_0-mlogloss:0.58912
# [198]	validation_0-mlogloss:0.58909
# [199]	validation_0-mlogloss:0.58918
# [200]	validation_0-mlogloss:0.58918
# [201]	validation_0-mlogloss:0.58918
# [202]	validation_0-mlogloss:0.58920
# [203]	validation_0-mlogloss:0.58920
# [204]	validation_0-mlogloss:0.58918
# [205]	validation_0-mlogloss:0.58921
# [206]	validation_0-mlogloss:0.58921
# [207]	validation_0-mlogloss:0.58991
# [208]	validation_0-mlogloss:0.58989
# [209]	validation_0-mlogloss:0.58983
# [210]	validation_0-mlogloss:0.58987
# [211]	validation_0-mlogloss:0.58985
# [212]	validation_0-mlogloss:0.59040
# [213]	validation_0-mlogloss:0.59039
# [214]	validation_0-mlogloss:0.59034
# [215]	validation_0-mlogloss:0.59033
# [216]	validation_0-mlogloss:0.59034
# [217]	validation_0-mlogloss:0.59031
# [218]	validation_0-mlogloss:0.59033
# [219]	validation_0-mlogloss:0.59055
# [220]	validation_0-mlogloss:0.59102
# [221]	validation_0-mlogloss:0.59107
# [222]	validation_0-mlogloss:0.59108
# [223]	validation_0-mlogloss:0.59105
# [224]	validation_0-mlogloss:0.59102
# [225]	validation_0-mlogloss:0.59072
# [226]	validation_0-mlogloss:0.59073
# [227]	validation_0-mlogloss:0.59078
# [228]	validation_0-mlogloss:0.59075
# [229]	validation_0-mlogloss:0.59077
# [230]	validation_0-mlogloss:0.59076
# [231]	validation_0-mlogloss:0.59077
# [232]	validation_0-mlogloss:0.59072
# [233]	validation_0-mlogloss:0.59074
# [234]	validation_0-mlogloss:0.59076
# [235]	validation_0-mlogloss:0.59080
# [236]	validation_0-mlogloss:0.59066
# [237]	validation_0-mlogloss:0.59076
# [238]	validation_0-mlogloss:0.59281
# [239]	validation_0-mlogloss:0.59285
# [240]	validation_0-mlogloss:0.59272
# [241]	validation_0-mlogloss:0.59297
# [242]	validation_0-mlogloss:0.59295
# [243]	validation_0-mlogloss:0.59294
# [244]	validation_0-mlogloss:0.59288
# [245]	validation_0-mlogloss:0.59294
# [246]	validation_0-mlogloss:0.59298
# [247]	validation_0-mlogloss:0.59296
# [248]	validation_0-mlogloss:0.59268
# [249]	validation_0-mlogloss:0.59267
# [250]	validation_0-mlogloss:0.59319
# [251]	validation_0-mlogloss:0.59319
# [252]	validation_0-mlogloss:0.59355
# [253]	validation_0-mlogloss:0.59463
# [254]	validation_0-mlogloss:0.59460
# [255]	validation_0-mlogloss:0.59466
# [256]	validation_0-mlogloss:0.59469
# [257]	validation_0-mlogloss:0.59464
# [258]	validation_0-mlogloss:0.59466
# [259]	validation_0-mlogloss:0.59462
# [260]	validation_0-mlogloss:0.59461
# [261]	validation_0-mlogloss:0.59463
# [262]	validation_0-mlogloss:0.59462
# [263]	validation_0-mlogloss:0.59465
# [264]	validation_0-mlogloss:0.59464
# [265]	validation_0-mlogloss:0.59459
# [266]	validation_0-mlogloss:0.59454
# [267]	validation_0-mlogloss:0.59457
# [268]	validation_0-mlogloss:0.59455
# [269]	validation_0-mlogloss:0.59473
# [270]	validation_0-mlogloss:0.59470
# [271]	validation_0-mlogloss:0.59468
# [272]	validation_0-mlogloss:0.59469
# [273]	validation_0-mlogloss:0.59471
# [274]	validation_0-mlogloss:0.59475
# [275]	validation_0-mlogloss:0.59475
# [276]	validation_0-mlogloss:0.59477
# [277]	validation_0-mlogloss:0.59475
# [278]	validation_0-mlogloss:0.59476
# [279]	validation_0-mlogloss:0.59472
# [280]	validation_0-mlogloss:0.59473
# [281]	validation_0-mlogloss:0.59472
# [282]	validation_0-mlogloss:0.59468
# [283]	validation_0-mlogloss:0.59471
# [284]	validation_0-mlogloss:0.59466
# [285]	validation_0-mlogloss:0.59471
# [286]	validation_0-mlogloss:0.59469
# [287]	validation_0-mlogloss:0.59468
# [288]	validation_0-mlogloss:0.59472
# [289]	validation_0-mlogloss:0.59474
# [290]	validation_0-mlogloss:0.59474
# [291]	validation_0-mlogloss:0.59477
# [292]	validation_0-mlogloss:0.59477
# [293]	validation_0-mlogloss:0.59539
# [294]	validation_0-mlogloss:0.59538
# [295]	validation_0-mlogloss:0.59541
# [296]	validation_0-mlogloss:0.59566
# [297]	validation_0-mlogloss:0.59566
# [298]	validation_0-mlogloss:0.59567
# [299]	validation_0-mlogloss:0.59571
# [300]	validation_0-mlogloss:0.59576
# [301]	validation_0-mlogloss:0.59716
# [302]	validation_0-mlogloss:0.59718
# [303]	validation_0-mlogloss:0.59715
# [304]	validation_0-mlogloss:0.59713
# [305]	validation_0-mlogloss:0.59718
# [306]	validation_0-mlogloss:0.59715
# [307]	validation_0-mlogloss:0.59711
# [308]	validation_0-mlogloss:0.59711
# [309]	validation_0-mlogloss:0.59719
# [310]	validation_0-mlogloss:0.59717
# [311]	validation_0-mlogloss:0.59722
# [312]	validation_0-mlogloss:0.59722
# [313]	validation_0-mlogloss:0.59720
# [314]	validation_0-mlogloss:0.59715
# [315]	validation_0-mlogloss:0.59711
# [316]	validation_0-mlogloss:0.59712
# [317]	validation_0-mlogloss:0.59717
# [318]	validation_0-mlogloss:0.59717
# [319]	validation_0-mlogloss:0.59717
# [320]	validation_0-mlogloss:0.59710
# [321]	validation_0-mlogloss:0.59707
# [322]	validation_0-mlogloss:0.59707
# [323]	validation_0-mlogloss:0.59704
# [324]	validation_0-mlogloss:0.59704
# [325]	validation_0-mlogloss:0.59705
# [326]	validation_0-mlogloss:0.59708
# [327]	validation_0-mlogloss:0.59709
# [328]	validation_0-mlogloss:0.59711
# [329]	validation_0-mlogloss:0.59714
# [330]	validation_0-mlogloss:0.59720
# [331]	validation_0-mlogloss:0.59719
# [332]	validation_0-mlogloss:0.59718
# [333]	validation_0-mlogloss:0.59718
# [334]	validation_0-mlogloss:0.59716
# [335]	validation_0-mlogloss:0.59713
# [336]	validation_0-mlogloss:0.59711
# [337]	validation_0-mlogloss:0.59711
# [338]	validation_0-mlogloss:0.59712
# [339]	validation_0-mlogloss:0.59708
# [340]	validation_0-mlogloss:0.59708
# [341]	validation_0-mlogloss:0.59713
# [342]	validation_0-mlogloss:0.59716
# [343]	validation_0-mlogloss:0.59717
# [344]	validation_0-mlogloss:0.59717
# [345]	validation_0-mlogloss:0.59720
# [346]	validation_0-mlogloss:0.59722
# [347]	validation_0-mlogloss:0.59716
# [348]	validation_0-mlogloss:0.59719
# [349]	validation_0-mlogloss:0.59721
# [350]	validation_0-mlogloss:0.59721
# [351]	validation_0-mlogloss:0.59725
# [352]	validation_0-mlogloss:0.59717
# [353]	validation_0-mlogloss:0.59716
# [354]	validation_0-mlogloss:0.59704
# [355]	validation_0-mlogloss:0.59701
# [356]	validation_0-mlogloss:0.59703
# [357]	validation_0-mlogloss:0.59701
# [358]	validation_0-mlogloss:0.59702
# [359]	validation_0-mlogloss:0.59709
# [360]	validation_0-mlogloss:0.59706
# [361]	validation_0-mlogloss:0.59704
# [362]	validation_0-mlogloss:0.59705
# [363]	validation_0-mlogloss:0.59704
# [364]	validation_0-mlogloss:0.59698
# [365]	validation_0-mlogloss:0.59696
# [366]	validation_0-mlogloss:0.59746
# [367]	validation_0-mlogloss:0.59742
# [368]	validation_0-mlogloss:0.59738
# [369]	validation_0-mlogloss:0.59763
# [370]	validation_0-mlogloss:0.59765
# [371]	validation_0-mlogloss:0.59764
# [372]	validation_0-mlogloss:0.59746
# [373]	validation_0-mlogloss:0.59754
# [374]	validation_0-mlogloss:0.59755
# [375]	validation_0-mlogloss:0.59746
# [376]	validation_0-mlogloss:0.59742
# [377]	validation_0-mlogloss:0.59740
# [378]	validation_0-mlogloss:0.59743
# [379]	validation_0-mlogloss:0.59747
# [380]	validation_0-mlogloss:0.59755
# [381]	validation_0-mlogloss:0.59763
# [382]	validation_0-mlogloss:0.59760
# [383]	validation_0-mlogloss:0.59763
# [384]	validation_0-mlogloss:0.59758
# [385]	validation_0-mlogloss:0.59758
# [386]	validation_0-mlogloss:0.59757
# [387]	validation_0-mlogloss:0.59754
# [388]	validation_0-mlogloss:0.59756
# [389]	validation_0-mlogloss:0.59750
# [390]	validation_0-mlogloss:0.59752
# [391]	validation_0-mlogloss:0.59754
# [392]	validation_0-mlogloss:0.59751
# [393]	validation_0-mlogloss:0.59756
# [394]	validation_0-mlogloss:0.59752
# [395]	validation_0-mlogloss:0.59753
# [396]	validation_0-mlogloss:0.59753
# [397]	validation_0-mlogloss:0.59752
# [398]	validation_0-mlogloss:0.59753
# [399]	validation_0-mlogloss:0.59762
# [400]	validation_0-mlogloss:0.59782
# [401]	validation_0-mlogloss:0.59784
# [402]	validation_0-mlogloss:0.59782
# [403]	validation_0-mlogloss:0.59782
# [404]	validation_0-mlogloss:0.59783
# [405]	validation_0-mlogloss:0.59786
# [406]	validation_0-mlogloss:0.59730
# [407]	validation_0-mlogloss:0.59722
# [408]	validation_0-mlogloss:0.59736
# [409]	validation_0-mlogloss:0.59746
# [410]	validation_0-mlogloss:0.59748
# [411]	validation_0-mlogloss:0.59751
# [412]	validation_0-mlogloss:0.59749
# [413]	validation_0-mlogloss:0.59747
# [414]	validation_0-mlogloss:0.59748
# [415]	validation_0-mlogloss:0.59751
# [416]	validation_0-mlogloss:0.59748
# [417]	validation_0-mlogloss:0.59751
# [418]	validation_0-mlogloss:0.59751
# [419]	validation_0-mlogloss:0.59755
# [420]	validation_0-mlogloss:0.59754
# [421]	validation_0-mlogloss:0.59764
# [422]	validation_0-mlogloss:0.59761
# [423]	validation_0-mlogloss:0.59764
# [424]	validation_0-mlogloss:0.59767
# [425]	validation_0-mlogloss:0.59804
# [426]	validation_0-mlogloss:0.59844
# [427]	validation_0-mlogloss:0.59845
# [428]	validation_0-mlogloss:0.59847
# [429]	validation_0-mlogloss:0.59849
# [430]	validation_0-mlogloss:0.59846
# [431]	validation_0-mlogloss:0.59846
# [432]	validation_0-mlogloss:0.59848
# [433]	validation_0-mlogloss:0.59845
# [434]	validation_0-mlogloss:0.59843
# [435]	validation_0-mlogloss:0.59847
# [436]	validation_0-mlogloss:0.59836
# [437]	validation_0-mlogloss:0.59836
# [438]	validation_0-mlogloss:0.59838
# [439]	validation_0-mlogloss:0.59841
# [440]	validation_0-mlogloss:0.59848
# [441]	validation_0-mlogloss:0.59846
# [442]	validation_0-mlogloss:0.59848
# [443]	validation_0-mlogloss:0.59846
# [444]	validation_0-mlogloss:0.59842
# [445]	validation_0-mlogloss:0.59841
# [446]	validation_0-mlogloss:0.59841
# [447]	validation_0-mlogloss:0.59839
# [448]	validation_0-mlogloss:0.59840
# [449]	validation_0-mlogloss:0.59839
# [450]	validation_0-mlogloss:0.59839
# [451]	validation_0-mlogloss:0.59838
# [452]	validation_0-mlogloss:0.59838
# [453]	validation_0-mlogloss:0.59837
# [454]	validation_0-mlogloss:0.59834
# [455]	validation_0-mlogloss:0.59849
# [456]	validation_0-mlogloss:0.59849
# [457]	validation_0-mlogloss:0.59848
# [458]	validation_0-mlogloss:0.59858
# [459]	validation_0-mlogloss:0.59844
# [460]	validation_0-mlogloss:0.59840
# [461]	validation_0-mlogloss:0.59846
# [462]	validation_0-mlogloss:0.59846
# [463]	validation_0-mlogloss:0.59843
# [464]	validation_0-mlogloss:0.59840
# [465]	validation_0-mlogloss:0.59842
# [466]	validation_0-mlogloss:0.59845
# [467]	validation_0-mlogloss:0.59844
# [468]	validation_0-mlogloss:0.59842
# [469]	validation_0-mlogloss:0.59841
# [470]	validation_0-mlogloss:0.59841
# [471]	validation_0-mlogloss:0.59838
# [472]	validation_0-mlogloss:0.59838
# [473]	validation_0-mlogloss:0.59833
# [474]	validation_0-mlogloss:0.59831
# [475]	validation_0-mlogloss:0.59831
# [476]	validation_0-mlogloss:0.59829
# [477]	validation_0-mlogloss:0.59831
# [478]	validation_0-mlogloss:0.59827
# [479]	validation_0-mlogloss:0.59830
# [480]	validation_0-mlogloss:0.59830
# [481]	validation_0-mlogloss:0.59828
# [482]	validation_0-mlogloss:0.59830
# [483]	validation_0-mlogloss:0.59836
# [484]	validation_0-mlogloss:0.59863
# [485]	validation_0-mlogloss:0.59864
# [486]	validation_0-mlogloss:0.59863
# [487]	validation_0-mlogloss:0.59862
# [488]	validation_0-mlogloss:0.59860
# [489]	validation_0-mlogloss:0.59860
# [490]	validation_0-mlogloss:0.59856
# [491]	validation_0-mlogloss:0.59858
# [492]	validation_0-mlogloss:0.59865
# [493]	validation_0-mlogloss:0.59864
# [494]	validation_0-mlogloss:0.59859
# [495]	validation_0-mlogloss:0.59861
# [496]	validation_0-mlogloss:0.59858
# [497]	validation_0-mlogloss:0.59855
# [498]	validation_0-mlogloss:0.59859
# [499]	validation_0-mlogloss:0.59887
# Epoch 1/50
# 8022/8022 ━━━━━━━━━━━━━━━━━━━━ 12s 1ms/step - accuracy: 0.6923 - loss: 0.5855 - val_accuracy: 0.7063 - val_loss: 0.5636
# Epoch 2/50
# 8022/8022 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - accuracy: 0.6984 - loss: 0.5777 - val_accuracy: 0.7074 - val_loss: 0.5682
# Epoch 3/50
# 8022/8022 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - accuracy: 0.7000 - loss: 0.5755 - val_accuracy: 0.7022 - val_loss: 0.5674
# Epoch 4/50
# 8022/8022 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - accuracy: 0.7003 - loss: 0.5743 - val_accuracy: 0.6861 - val_loss: 0.5900
# Epoch 5/50
# 8022/8022 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - accuracy: 0.7003 - loss: 0.5732 - val_accuracy: 0.7138 - val_loss: 0.5564
# Epoch 6/50
# 8022/8022 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - accuracy: 0.7009 - loss: 0.5729 - val_accuracy: 0.7193 - val_loss: 0.5571
# Epoch 7/50
# 8022/8022 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - accuracy: 0.7006 - loss: 0.5725 - val_accuracy: 0.7147 - val_loss: 0.5590
# Epoch 8/50
# 8022/8022 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - accuracy: 0.7006 - loss: 0.5722 - val_accuracy: 0.7172 - val_loss: 0.5554
# Epoch 9/50
# 8022/8022 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - accuracy: 0.7018 - loss: 0.5716 - val_accuracy: 0.7200 - val_loss: 0.5511
# Epoch 10/50
# 8022/8022 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - accuracy: 0.7012 - loss: 0.5719 - val_accuracy: 0.7139 - val_loss: 0.5542
# Epoch 11/50
# 8022/8022 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - accuracy: 0.7018 - loss: 0.5714 - val_accuracy: 0.7199 - val_loss: 0.5534
# Epoch 12/50
# 8022/8022 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - accuracy: 0.7011 - loss: 0.5712 - val_accuracy: 0.7218 - val_loss: 0.5496
# Epoch 13/50
# 8022/8022 ━━━━━━━━━━━━━━━━━━━━ 15s 2ms/step - accuracy: 0.7008 - loss: 0.5716 - val_accuracy: 0.7195 - val_loss: 0.5555
# Epoch 14/50
# 8022/8022 ━━━━━━━━━━━━━━━━━━━━ 15s 2ms/step - accuracy: 0.7010 - loss: 0.5710 - val_accuracy: 0.7109 - val_loss: 0.5566
# Epoch 15/50
# 8022/8022 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - accuracy: 0.7019 - loss: 0.5707 - val_accuracy: 0.7149 - val_loss: 0.5547
# Epoch 16/50
# 8022/8022 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - accuracy: 0.7013 - loss: 0.5706 - val_accuracy: 0.7210 - val_loss: 0.5599
# Epoch 17/50
# 8022/8022 ━━━━━━━━━━━━━━━━━━━━ 15s 2ms/step - accuracy: 0.7019 - loss: 0.5705 - val_accuracy: 0.7071 - val_loss: 0.5588

# %%
# ----------------------------
# Save models and preprocessing objects
# ----------------------------
joblib.dump(forest_model, 'forest_model.pkl')
joblib.dump(xgb_model, 'xgb_model.pkl')
joblib.dump(label_encoder, 'label_encoder.pkl')
joblib.dump(scaler_tabular, 'scaler_tabular.pkl')
joblib.dump(scaler_long, 'scaler_long.pkl')
neural_model.save('neural_model.keras')
