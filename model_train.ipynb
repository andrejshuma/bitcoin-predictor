# %%
import joblib
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np

# %store -r export_df
df = export_df

# %store -r export_df_long
df_long = export_df_long

# ----------------------------
# Prepare Data
# ----------------------------
x = df.drop(columns=['activity'])
y = df['activity']

x_long = df_long.drop(columns=['activity'])
y_long = df_long['activity']

# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
y_long_encoded = label_encoder.fit_transform(y_long)

x = x.replace([np.inf, -np.inf], np.nan).dropna()
x_long = x_long.replace([np.inf, -np.inf], np.nan).dropna()

# Split data
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.1, random_state=42, shuffle=False
)

x_long_test = x_long[-100:]
y_long_test = y_long[-100:]
x_long_train = x_long[:-100]
y_long_train = y_long[:-100]

# Scale features
scaler_tabular = StandardScaler()
x_train_scaled = scaler_tabular.fit_transform(x_train)
x_test_scaled = scaler_tabular.transform(x_test)

scaler_long = StandardScaler()
x_long_train_scaled = scaler_long.fit_transform(x_long_train)
x_long_test_scaled = scaler_long.transform(x_long_test)

# Encode labels numerically
y_train_encoded = label_encoder.transform(y_train)
y_test_encoded = label_encoder.transform(y_test)
y_long_train_encoded = label_encoder.transform(y_long_train)
y_long_test_encoded = label_encoder.transform(y_long_test)

# ----------------------------
# Random Forest
# ----------------------------
forest_model = RandomForestClassifier(
    n_estimators=500,
    random_state=42,
    class_weight='balanced'
)
forest_model.fit(x_train_scaled, y_train_encoded)

# ----------------------------
# XGBoost
# ----------------------------
xgb_model = xgb.XGBClassifier(
    objective="multi:softprob",
    num_class=len(label_encoder.classes_),
    n_estimators=500,
    max_depth=8,
    learning_rate=0.15,
    gamma=1,
    reg_alpha=0.1,
    reg_lambda=1,
    subsample=0.8,
    colsample_bytree=0.8,
    eval_metric='mlogloss',
    use_label_encoder=False,
    random_state=42
)
xgb_model.fit(
    x_train_scaled,
    y_train_encoded,
    eval_set=[(x_test_scaled, y_test_encoded)],
    verbose=True
)


# ----------------------------
# Neural Network
# ----------------------------
neural_model = Sequential([
    Input(shape=(x_long_train_scaled.shape[1],)),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dense(len(label_encoder.classes_), activation='softmax')
])

neural_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

neural_model.fit(
    x_long_train_scaled,
    y_long_train_encoded,
    epochs=50,
    batch_size=32,
    validation_split=0.1,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# [0]	validation_0-mlogloss:0.66040
# [1]	validation_0-mlogloss:0.63333
# [2]	validation_0-mlogloss:0.62451
# [3]	validation_0-mlogloss:0.60533
# [4]	validation_0-mlogloss:0.59209
# [5]	validation_0-mlogloss:0.58825
# [6]	validation_0-mlogloss:0.58247
# [7]	validation_0-mlogloss:0.57869
# [8]	validation_0-mlogloss:0.57910
# [9]	validation_0-mlogloss:0.57920
# [10]	validation_0-mlogloss:0.57756
# [11]	validation_0-mlogloss:0.57816
# [12]	validation_0-mlogloss:0.57850
# [13]	validation_0-mlogloss:0.58070
# [14]	validation_0-mlogloss:0.57953
# [15]	validation_0-mlogloss:0.57831
# [16]	validation_0-mlogloss:0.57769
# [17]	validation_0-mlogloss:0.57869
# [18]	validation_0-mlogloss:0.57902
# [19]	validation_0-mlogloss:0.57747
# [20]	validation_0-mlogloss:0.57839
# [21]	validation_0-mlogloss:0.57925
# [22]	validation_0-mlogloss:0.58108
# [23]	validation_0-mlogloss:0.58034
# [24]	validation_0-mlogloss:0.58568
# [25]	validation_0-mlogloss:0.58596
# [26]	validation_0-mlogloss:0.58726
# [27]	validation_0-mlogloss:0.58718
# [28]	validation_0-mlogloss:0.58799
# [29]	validation_0-mlogloss:0.58896
# [30]	validation_0-mlogloss:0.58934
# [31]	validation_0-mlogloss:0.58904
# [32]	validation_0-mlogloss:0.59043
# [33]	validation_0-mlogloss:0.59040
# [34]	validation_0-mlogloss:0.59040
# [35]	validation_0-mlogloss:0.59047
# [36]	validation_0-mlogloss:0.59204
# [37]	validation_0-mlogloss:0.59202
# [38]	validation_0-mlogloss:0.59264
# [39]	validation_0-mlogloss:0.59257
# [40]	validation_0-mlogloss:0.59262
# [41]	validation_0-mlogloss:0.59214
# [42]	validation_0-mlogloss:0.59212
# [43]	validation_0-mlogloss:0.59211
# [44]	validation_0-mlogloss:0.59216
# [45]	validation_0-mlogloss:0.59223
# [46]	validation_0-mlogloss:0.59227
# [47]	validation_0-mlogloss:0.59233
# [48]	validation_0-mlogloss:0.59245
# [49]	validation_0-mlogloss:0.59240
# C:\Users\borja\PycharmProjects\bitcoin-predictor\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [14:41:49] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [50]	validation_0-mlogloss:0.59289
# [51]	validation_0-mlogloss:0.59290
# [52]	validation_0-mlogloss:0.59292
# [53]	validation_0-mlogloss:0.59291
# [54]	validation_0-mlogloss:0.59336
# [55]	validation_0-mlogloss:0.59326
# [56]	validation_0-mlogloss:0.59322
# [57]	validation_0-mlogloss:0.59330
# [58]	validation_0-mlogloss:0.59332
# [59]	validation_0-mlogloss:0.59329
# [60]	validation_0-mlogloss:0.59334
# [61]	validation_0-mlogloss:0.59336
# [62]	validation_0-mlogloss:0.59333
# [63]	validation_0-mlogloss:0.59328
# [64]	validation_0-mlogloss:0.59328
# [65]	validation_0-mlogloss:0.59330
# [66]	validation_0-mlogloss:0.59335
# [67]	validation_0-mlogloss:0.59336
# [68]	validation_0-mlogloss:0.59335
# [69]	validation_0-mlogloss:0.59280
# [70]	validation_0-mlogloss:0.59282
# [71]	validation_0-mlogloss:0.59334
# [72]	validation_0-mlogloss:0.59332
# [73]	validation_0-mlogloss:0.59327
# [74]	validation_0-mlogloss:0.59336
# [75]	validation_0-mlogloss:0.59331
# [76]	validation_0-mlogloss:0.59314
# [77]	validation_0-mlogloss:0.59318
# [78]	validation_0-mlogloss:0.59305
# [79]	validation_0-mlogloss:0.59306
# [80]	validation_0-mlogloss:0.59314
# [81]	validation_0-mlogloss:0.59362
# [82]	validation_0-mlogloss:0.59411
# [83]	validation_0-mlogloss:0.59416
# [84]	validation_0-mlogloss:0.59369
# [85]	validation_0-mlogloss:0.59425
# [86]	validation_0-mlogloss:0.59421
# [87]	validation_0-mlogloss:0.59413
# [88]	validation_0-mlogloss:0.59460
# [89]	validation_0-mlogloss:0.59455
# [90]	validation_0-mlogloss:0.59505
# [91]	validation_0-mlogloss:0.59508
# [92]	validation_0-mlogloss:0.59537
# [93]	validation_0-mlogloss:0.59537
# [94]	validation_0-mlogloss:0.59532
# [95]	validation_0-mlogloss:0.59532
# [96]	validation_0-mlogloss:0.59640
# [97]	validation_0-mlogloss:0.59681
# [98]	validation_0-mlogloss:0.59692
# [99]	validation_0-mlogloss:0.59690
# [100]	validation_0-mlogloss:0.59724
# [101]	validation_0-mlogloss:0.59730
# [102]	validation_0-mlogloss:0.59726
# [103]	validation_0-mlogloss:0.59728
# [104]	validation_0-mlogloss:0.59727
# [105]	validation_0-mlogloss:0.59727
# [106]	validation_0-mlogloss:0.59741
# [107]	validation_0-mlogloss:0.59737
# [108]	validation_0-mlogloss:0.59737
# [109]	validation_0-mlogloss:0.59735
# [110]	validation_0-mlogloss:0.59731
# [111]	validation_0-mlogloss:0.59735
# [112]	validation_0-mlogloss:0.59735
# [113]	validation_0-mlogloss:0.59748
# [114]	validation_0-mlogloss:0.59729
# [115]	validation_0-mlogloss:0.59724
# [116]	validation_0-mlogloss:0.59732
# [117]	validation_0-mlogloss:0.59733
# [118]	validation_0-mlogloss:0.59732
# [119]	validation_0-mlogloss:0.59729
# [120]	validation_0-mlogloss:0.59725
# [121]	validation_0-mlogloss:0.59727
# [122]	validation_0-mlogloss:0.59720
# [123]	validation_0-mlogloss:0.59723
# [124]	validation_0-mlogloss:0.59726
# [125]	validation_0-mlogloss:0.59725
# [126]	validation_0-mlogloss:0.59725
# [127]	validation_0-mlogloss:0.59728
# [128]	validation_0-mlogloss:0.59734
# [129]	validation_0-mlogloss:0.59750
# [130]	validation_0-mlogloss:0.59757
# [131]	validation_0-mlogloss:0.59752
# [132]	validation_0-mlogloss:0.59767
# [133]	validation_0-mlogloss:0.59775
# [134]	validation_0-mlogloss:0.59771
# [135]	validation_0-mlogloss:0.59769
# [136]	validation_0-mlogloss:0.59776
# [137]	validation_0-mlogloss:0.59775
# [138]	validation_0-mlogloss:0.59769
# [139]	validation_0-mlogloss:0.59775
# [140]	validation_0-mlogloss:0.59774
# [141]	validation_0-mlogloss:0.59779
# [142]	validation_0-mlogloss:0.59779
# [143]	validation_0-mlogloss:0.59780
# [144]	validation_0-mlogloss:0.59783
# [145]	validation_0-mlogloss:0.59782
# [146]	validation_0-mlogloss:0.59788
# [147]	validation_0-mlogloss:0.59787
# [148]	validation_0-mlogloss:0.59780
# [149]	validation_0-mlogloss:0.59773
# [150]	validation_0-mlogloss:0.59779
# [151]	validation_0-mlogloss:0.59774
# [152]	validation_0-mlogloss:0.59796
# [153]	validation_0-mlogloss:0.59793
# [154]	validation_0-mlogloss:0.59801
# [155]	validation_0-mlogloss:0.59925
# [156]	validation_0-mlogloss:0.59937
# [157]	validation_0-mlogloss:0.59941
# [158]	validation_0-mlogloss:0.59945
# [159]	validation_0-mlogloss:0.59943
# [160]	validation_0-mlogloss:0.59939
# [161]	validation_0-mlogloss:0.59939
# [162]	validation_0-mlogloss:0.60003
# [163]	validation_0-mlogloss:0.60011
# [164]	validation_0-mlogloss:0.60012
# [165]	validation_0-mlogloss:0.60007
# [166]	validation_0-mlogloss:0.60003
# [167]	validation_0-mlogloss:0.60002
# [168]	validation_0-mlogloss:0.59995
# [169]	validation_0-mlogloss:0.60013
# [170]	validation_0-mlogloss:0.60012
# [171]	validation_0-mlogloss:0.60020
# [172]	validation_0-mlogloss:0.60024
# [173]	validation_0-mlogloss:0.60019
# [174]	validation_0-mlogloss:0.60020
# [175]	validation_0-mlogloss:0.60016
# [176]	validation_0-mlogloss:0.60011
# [177]	validation_0-mlogloss:0.60007
# [178]	validation_0-mlogloss:0.60052
# [179]	validation_0-mlogloss:0.60047
# [180]	validation_0-mlogloss:0.60046
# [181]	validation_0-mlogloss:0.60045
# [182]	validation_0-mlogloss:0.60118
# [183]	validation_0-mlogloss:0.60118
# [184]	validation_0-mlogloss:0.60113
# [185]	validation_0-mlogloss:0.60116
# [186]	validation_0-mlogloss:0.60121
# [187]	validation_0-mlogloss:0.60120
# [188]	validation_0-mlogloss:0.60164
# [189]	validation_0-mlogloss:0.60168
# [190]	validation_0-mlogloss:0.60170
# [191]	validation_0-mlogloss:0.60174
# [192]	validation_0-mlogloss:0.60179
# [193]	validation_0-mlogloss:0.60185
# [194]	validation_0-mlogloss:0.60194
# [195]	validation_0-mlogloss:0.60185
# [196]	validation_0-mlogloss:0.60220
# [197]	validation_0-mlogloss:0.60218
# [198]	validation_0-mlogloss:0.60212
# [199]	validation_0-mlogloss:0.60173
# [200]	validation_0-mlogloss:0.60267
# [201]	validation_0-mlogloss:0.60266
# [202]	validation_0-mlogloss:0.60267
# [203]	validation_0-mlogloss:0.60276
# [204]	validation_0-mlogloss:0.60282
# [205]	validation_0-mlogloss:0.60286
# [206]	validation_0-mlogloss:0.60429
# [207]	validation_0-mlogloss:0.60424
# [208]	validation_0-mlogloss:0.60426
# [209]	validation_0-mlogloss:0.60429
# [210]	validation_0-mlogloss:0.60426
# [211]	validation_0-mlogloss:0.60433
# [212]	validation_0-mlogloss:0.60435
# [213]	validation_0-mlogloss:0.60433
# [214]	validation_0-mlogloss:0.60432
# [215]	validation_0-mlogloss:0.60434
# [216]	validation_0-mlogloss:0.60430
# [217]	validation_0-mlogloss:0.60431
# [218]	validation_0-mlogloss:0.60434
# [219]	validation_0-mlogloss:0.60427
# [220]	validation_0-mlogloss:0.60429
# [221]	validation_0-mlogloss:0.60423
# [222]	validation_0-mlogloss:0.60417
# [223]	validation_0-mlogloss:0.60414
# [224]	validation_0-mlogloss:0.60409
# [225]	validation_0-mlogloss:0.60373
# [226]	validation_0-mlogloss:0.60429
# [227]	validation_0-mlogloss:0.60430
# [228]	validation_0-mlogloss:0.60434
# [229]	validation_0-mlogloss:0.60422
# [230]	validation_0-mlogloss:0.60423
# [231]	validation_0-mlogloss:0.60425
# [232]	validation_0-mlogloss:0.60424
# [233]	validation_0-mlogloss:0.60421
# [234]	validation_0-mlogloss:0.60428
# [235]	validation_0-mlogloss:0.60423
# [236]	validation_0-mlogloss:0.60426
# [237]	validation_0-mlogloss:0.60431
# [238]	validation_0-mlogloss:0.60436
# [239]	validation_0-mlogloss:0.60434
# [240]	validation_0-mlogloss:0.60440
# [241]	validation_0-mlogloss:0.60444
# [242]	validation_0-mlogloss:0.60444
# [243]	validation_0-mlogloss:0.60443
# [244]	validation_0-mlogloss:0.60444
# [245]	validation_0-mlogloss:0.60447
# [246]	validation_0-mlogloss:0.60448
# [247]	validation_0-mlogloss:0.60451
# [248]	validation_0-mlogloss:0.60456
# [249]	validation_0-mlogloss:0.60487
# [250]	validation_0-mlogloss:0.60484
# [251]	validation_0-mlogloss:0.60480
# [252]	validation_0-mlogloss:0.60498
# [253]	validation_0-mlogloss:0.60494
# [254]	validation_0-mlogloss:0.60495
# [255]	validation_0-mlogloss:0.60495
# [256]	validation_0-mlogloss:0.60494
# [257]	validation_0-mlogloss:0.60509
# [258]	validation_0-mlogloss:0.60513
# [259]	validation_0-mlogloss:0.60515
# [260]	validation_0-mlogloss:0.60514
# [261]	validation_0-mlogloss:0.60512
# [262]	validation_0-mlogloss:0.60509
# [263]	validation_0-mlogloss:0.60504
# [264]	validation_0-mlogloss:0.60407
# [265]	validation_0-mlogloss:0.60406
# [266]	validation_0-mlogloss:0.60405
# [267]	validation_0-mlogloss:0.60405
# [268]	validation_0-mlogloss:0.60405
# [269]	validation_0-mlogloss:0.60408
# [270]	validation_0-mlogloss:0.60421
# [271]	validation_0-mlogloss:0.60419
# [272]	validation_0-mlogloss:0.60415
# [273]	validation_0-mlogloss:0.60419
# [274]	validation_0-mlogloss:0.60418
# [275]	validation_0-mlogloss:0.60415
# [276]	validation_0-mlogloss:0.60413
# [277]	validation_0-mlogloss:0.60420
# [278]	validation_0-mlogloss:0.60417
# [279]	validation_0-mlogloss:0.60411
# [280]	validation_0-mlogloss:0.60401
# [281]	validation_0-mlogloss:0.60395
# [282]	validation_0-mlogloss:0.60406
# [283]	validation_0-mlogloss:0.60403
# [284]	validation_0-mlogloss:0.60408
# [285]	validation_0-mlogloss:0.60411
# [286]	validation_0-mlogloss:0.60413
# [287]	validation_0-mlogloss:0.60439
# [288]	validation_0-mlogloss:0.60419
# [289]	validation_0-mlogloss:0.60419
# [290]	validation_0-mlogloss:0.60426
# [291]	validation_0-mlogloss:0.60422
# [292]	validation_0-mlogloss:0.60423
# [293]	validation_0-mlogloss:0.60411
# [294]	validation_0-mlogloss:0.60414
# [295]	validation_0-mlogloss:0.60409
# [296]	validation_0-mlogloss:0.60392
# [297]	validation_0-mlogloss:0.60399
# [298]	validation_0-mlogloss:0.60396
# [299]	validation_0-mlogloss:0.60400
# [300]	validation_0-mlogloss:0.60394
# [301]	validation_0-mlogloss:0.60397
# [302]	validation_0-mlogloss:0.60395
# [303]	validation_0-mlogloss:0.60395
# [304]	validation_0-mlogloss:0.60340
# [305]	validation_0-mlogloss:0.60338
# [306]	validation_0-mlogloss:0.60338
# [307]	validation_0-mlogloss:0.60332
# [308]	validation_0-mlogloss:0.60332
# [309]	validation_0-mlogloss:0.60324
# [310]	validation_0-mlogloss:0.60326
# [311]	validation_0-mlogloss:0.60321
# [312]	validation_0-mlogloss:0.60315
# [313]	validation_0-mlogloss:0.60318
# [314]	validation_0-mlogloss:0.60321
# [315]	validation_0-mlogloss:0.60331
# [316]	validation_0-mlogloss:0.60337
# [317]	validation_0-mlogloss:0.60332
# [318]	validation_0-mlogloss:0.60329
# [319]	validation_0-mlogloss:0.60336
# [320]	validation_0-mlogloss:0.60339
# [321]	validation_0-mlogloss:0.60340
# [322]	validation_0-mlogloss:0.60336
# [323]	validation_0-mlogloss:0.60337
# [324]	validation_0-mlogloss:0.60332
# [325]	validation_0-mlogloss:0.60332
# [326]	validation_0-mlogloss:0.60335
# [327]	validation_0-mlogloss:0.60464
# [328]	validation_0-mlogloss:0.60465
# [329]	validation_0-mlogloss:0.60461
# [330]	validation_0-mlogloss:0.60465
# [331]	validation_0-mlogloss:0.60464
# [332]	validation_0-mlogloss:0.60452
# [333]	validation_0-mlogloss:0.60530
# [334]	validation_0-mlogloss:0.60531
# [335]	validation_0-mlogloss:0.60531
# [336]	validation_0-mlogloss:0.60528
# [337]	validation_0-mlogloss:0.60526
# [338]	validation_0-mlogloss:0.60528
# [339]	validation_0-mlogloss:0.60523
# [340]	validation_0-mlogloss:0.60523
# [341]	validation_0-mlogloss:0.60521
# [342]	validation_0-mlogloss:0.60519
# [343]	validation_0-mlogloss:0.60522
# [344]	validation_0-mlogloss:0.60528
# [345]	validation_0-mlogloss:0.60526
# [346]	validation_0-mlogloss:0.60526
# [347]	validation_0-mlogloss:0.60527
# [348]	validation_0-mlogloss:0.60522
# [349]	validation_0-mlogloss:0.60529
# [350]	validation_0-mlogloss:0.60531
# [351]	validation_0-mlogloss:0.60529
# [352]	validation_0-mlogloss:0.60533
# [353]	validation_0-mlogloss:0.60536
# [354]	validation_0-mlogloss:0.60541
# [355]	validation_0-mlogloss:0.60541
# [356]	validation_0-mlogloss:0.60579
# [357]	validation_0-mlogloss:0.60578
# [358]	validation_0-mlogloss:0.60573
# [359]	validation_0-mlogloss:0.60612
# [360]	validation_0-mlogloss:0.60578
# [361]	validation_0-mlogloss:0.60581
# [362]	validation_0-mlogloss:0.60583
# [363]	validation_0-mlogloss:0.60585
# [364]	validation_0-mlogloss:0.60581
# [365]	validation_0-mlogloss:0.60579
# [366]	validation_0-mlogloss:0.60580
# [367]	validation_0-mlogloss:0.60583
# [368]	validation_0-mlogloss:0.60580
# [369]	validation_0-mlogloss:0.60579
# [370]	validation_0-mlogloss:0.60582
# [371]	validation_0-mlogloss:0.60579
# [372]	validation_0-mlogloss:0.60581
# [373]	validation_0-mlogloss:0.60587
# [374]	validation_0-mlogloss:0.60584
# [375]	validation_0-mlogloss:0.60584
# [376]	validation_0-mlogloss:0.60579
# [377]	validation_0-mlogloss:0.60581
# [378]	validation_0-mlogloss:0.60573
# [379]	validation_0-mlogloss:0.60566
# [380]	validation_0-mlogloss:0.60566
# [381]	validation_0-mlogloss:0.60567
# [382]	validation_0-mlogloss:0.60570
# [383]	validation_0-mlogloss:0.60578
# [384]	validation_0-mlogloss:0.60570
# [385]	validation_0-mlogloss:0.60566
# [386]	validation_0-mlogloss:0.60567
# [387]	validation_0-mlogloss:0.60573
# [388]	validation_0-mlogloss:0.60574
# [389]	validation_0-mlogloss:0.60597
# [390]	validation_0-mlogloss:0.60595
# [391]	validation_0-mlogloss:0.60601
# [392]	validation_0-mlogloss:0.60607
# [393]	validation_0-mlogloss:0.60599
# [394]	validation_0-mlogloss:0.60595
# [395]	validation_0-mlogloss:0.60588
# [396]	validation_0-mlogloss:0.60592
# [397]	validation_0-mlogloss:0.60592
# [398]	validation_0-mlogloss:0.60589
# [399]	validation_0-mlogloss:0.60590
# [400]	validation_0-mlogloss:0.60592
# [401]	validation_0-mlogloss:0.60594
# [402]	validation_0-mlogloss:0.60595
# [403]	validation_0-mlogloss:0.60582
# [404]	validation_0-mlogloss:0.60587
# [405]	validation_0-mlogloss:0.60590
# [406]	validation_0-mlogloss:0.60618
# [407]	validation_0-mlogloss:0.60622
# [408]	validation_0-mlogloss:0.60614
# [409]	validation_0-mlogloss:0.60605
# [410]	validation_0-mlogloss:0.60606
# [411]	validation_0-mlogloss:0.60608
# [412]	validation_0-mlogloss:0.60614
# [413]	validation_0-mlogloss:0.60607
# [414]	validation_0-mlogloss:0.60610
# [415]	validation_0-mlogloss:0.60611
# [416]	validation_0-mlogloss:0.60610
# [417]	validation_0-mlogloss:0.60610
# [418]	validation_0-mlogloss:0.60607
# [419]	validation_0-mlogloss:0.60610
# [420]	validation_0-mlogloss:0.60608
# [421]	validation_0-mlogloss:0.60597
# [422]	validation_0-mlogloss:0.60600
# [423]	validation_0-mlogloss:0.60595
# [424]	validation_0-mlogloss:0.60594
# [425]	validation_0-mlogloss:0.60577
# [426]	validation_0-mlogloss:0.60579
# [427]	validation_0-mlogloss:0.60581
# [428]	validation_0-mlogloss:0.60582
# [429]	validation_0-mlogloss:0.60580
# [430]	validation_0-mlogloss:0.60584
# [431]	validation_0-mlogloss:0.60584
# [432]	validation_0-mlogloss:0.60590
# [433]	validation_0-mlogloss:0.60586
# [434]	validation_0-mlogloss:0.60585
# [435]	validation_0-mlogloss:0.60582
# [436]	validation_0-mlogloss:0.60581
# [437]	validation_0-mlogloss:0.60582
# [438]	validation_0-mlogloss:0.60579
# [439]	validation_0-mlogloss:0.60585
# [440]	validation_0-mlogloss:0.60584
# [441]	validation_0-mlogloss:0.60544
# [442]	validation_0-mlogloss:0.60582
# [443]	validation_0-mlogloss:0.60581
# [444]	validation_0-mlogloss:0.60583
# [445]	validation_0-mlogloss:0.60575
# [446]	validation_0-mlogloss:0.60576
# [447]	validation_0-mlogloss:0.60575
# [448]	validation_0-mlogloss:0.60582
# [449]	validation_0-mlogloss:0.60582
# [450]	validation_0-mlogloss:0.60579
# [451]	validation_0-mlogloss:0.60575
# [452]	validation_0-mlogloss:0.60572
# [453]	validation_0-mlogloss:0.60574
# [454]	validation_0-mlogloss:0.60573
# [455]	validation_0-mlogloss:0.60577
# [456]	validation_0-mlogloss:0.60583
# [457]	validation_0-mlogloss:0.60583
# [458]	validation_0-mlogloss:0.60586
# [459]	validation_0-mlogloss:0.60587
# [460]	validation_0-mlogloss:0.60581
# [461]	validation_0-mlogloss:0.60576
# [462]	validation_0-mlogloss:0.60579
# [463]	validation_0-mlogloss:0.60580
# [464]	validation_0-mlogloss:0.60577
# [465]	validation_0-mlogloss:0.60579
# [466]	validation_0-mlogloss:0.60571
# [467]	validation_0-mlogloss:0.60577
# [468]	validation_0-mlogloss:0.60570
# [469]	validation_0-mlogloss:0.60571
# [470]	validation_0-mlogloss:0.60568
# [471]	validation_0-mlogloss:0.60571
# [472]	validation_0-mlogloss:0.60574
# [473]	validation_0-mlogloss:0.60578
# [474]	validation_0-mlogloss:0.60584
# [475]	validation_0-mlogloss:0.60709
# [476]	validation_0-mlogloss:0.60719
# [477]	validation_0-mlogloss:0.60719
# [478]	validation_0-mlogloss:0.60708
# [479]	validation_0-mlogloss:0.60707
# [480]	validation_0-mlogloss:0.60709
# [481]	validation_0-mlogloss:0.60710
# [482]	validation_0-mlogloss:0.60716
# [483]	validation_0-mlogloss:0.60716
# [484]	validation_0-mlogloss:0.60710
# [485]	validation_0-mlogloss:0.60714
# [486]	validation_0-mlogloss:0.60714
# [487]	validation_0-mlogloss:0.60714
# [488]	validation_0-mlogloss:0.60712
# [489]	validation_0-mlogloss:0.60712
# [490]	validation_0-mlogloss:0.60716
# [491]	validation_0-mlogloss:0.60715
# [492]	validation_0-mlogloss:0.60723
# [493]	validation_0-mlogloss:0.60724
# [494]	validation_0-mlogloss:0.60722
# [495]	validation_0-mlogloss:0.60719
# [496]	validation_0-mlogloss:0.60663
# [497]	validation_0-mlogloss:0.60667
# [498]	validation_0-mlogloss:0.60664
# [499]	validation_0-mlogloss:0.60667
# Epoch 1/50
# 8031/8031 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step - accuracy: 0.5133 - loss: 0.6934 - val_accuracy: 0.5001 - val_loss: 0.6947
# Epoch 2/50
# 8031/8031 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - accuracy: 0.5158 - loss: 0.6924 - val_accuracy: 0.5194 - val_loss: 0.6923
# Epoch 3/50
# 8031/8031 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - accuracy: 0.5173 - loss: 0.6922 - val_accuracy: 0.5175 - val_loss: 0.6926
# Epoch 4/50
# 8031/8031 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - accuracy: 0.5201 - loss: 0.6921 - val_accuracy: 0.5136 - val_loss: 0.6923
# Epoch 5/50
# 8031/8031 ━━━━━━━━━━━━━━━━━━━━ 25s 3ms/step - accuracy: 0.5179 - loss: 0.6921 - val_accuracy: 0.5257 - val_loss: 0.6924
# Epoch 6/50
# 8031/8031 ━━━━━━━━━━━━━━━━━━━━ 25s 3ms/step - accuracy: 0.5190 - loss: 0.6920 - val_accuracy: 0.5076 - val_loss: 0.6929
# Epoch 7/50
# 8031/8031 ━━━━━━━━━━━━━━━━━━━━ 33s 4ms/step - accuracy: 0.5204 - loss: 0.6919 - val_accuracy: 0.5174 - val_loss: 0.6935
# Epoch 8/50
# 8031/8031 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.5201 - loss: 0.6919 - val_accuracy: 0.5118 - val_loss: 0.6923
# Epoch 9/50
# 8031/8031 ━━━━━━━━━━━━━━━━━━━━ 36s 4ms/step - accuracy: 0.5207 - loss: 0.6918 - val_accuracy: 0.5203 - val_loss: 0.6921
# Epoch 10/50
# 8031/8031 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.5213 - loss: 0.6919 - val_accuracy: 0.5252 - val_loss: 0.6919
# Epoch 11/50
# 8031/8031 ━━━━━━━━━━━━━━━━━━━━ 42s 5ms/step - accuracy: 0.5210 - loss: 0.6919 - val_accuracy: 0.5023 - val_loss: 0.6925
# Epoch 12/50
# 8031/8031 ━━━━━━━━━━━━━━━━━━━━ 33s 4ms/step - accuracy: 0.5221 - loss: 0.6918 - val_accuracy: 0.5251 - val_loss: 0.6920
# Epoch 13/50
# 8031/8031 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.5227 - loss: 0.6918 - val_accuracy: 0.5129 - val_loss: 0.6925
# Epoch 14/50
# 8031/8031 ━━━━━━━━━━━━━━━━━━━━ 34s 4ms/step - accuracy: 0.5221 - loss: 0.6917 - val_accuracy: 0.5016 - val_loss: 0.6926
# Epoch 15/50
# 8031/8031 ━━━━━━━━━━━━━━━━━━━━ 36s 4ms/step - accuracy: 0.5227 - loss: 0.6917 - val_accuracy: 0.5128 - val_loss: 0.6924

# %%
# ----------------------------
# Save models and preprocessing objects
# ----------------------------
joblib.dump(forest_model, 'forest_model.pkl')
joblib.dump(xgb_model, 'models/xgb_model.pkl')
joblib.dump(label_encoder, 'models/label_encoder.pkl')
joblib.dump(scaler_tabular, 'models/scaler_tabular.pkl')
joblib.dump(scaler_long, 'models/scaler_long.pkl')
neural_model.save('neural_model.keras')
