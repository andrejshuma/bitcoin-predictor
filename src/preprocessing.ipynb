# %%
import pandas as pd

from utils.apis import fetch_binance_btc
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from utils.utils import get_technical_indicators, create_target_column

# %%
# df = fetch_binance_btc('15m', 365 * 1 + 3)
# df.to_csv("../data/btc_1yrs.csv")

# %%
# df = fetch_binance_btc('15m', 365 * 5 + 3)
# df.to_csv("../data/btc_5yrs.csv")

# %%
# df = fetch_binance_btc('15m', 365 * 10 + 3)
# df.to_csv("../data/btc_10yrs.csv")

# %%
df_1y = pd.read_csv("../data/btc_1yrs.csv")
df_1y.set_index('timestamp', inplace=True)

df_5y = pd.read_csv("../data/btc_5yrs.csv")
df_5y.set_index('timestamp', inplace=True)

df_10y = pd.read_csv("../data/btc_10yrs.csv")
df_10y.set_index('timestamp', inplace=True)

# %%
get_technical_indicators(df_1y)
get_technical_indicators(df_5y)
get_technical_indicators(df_10y)
# Out:
#                           open       high        low      close      volume  \
# timestamp
# 2017-08-17 21:00:00    4346.74    4367.93    4315.85    4367.93   10.556113
# 2017-08-17 21:15:00    4346.73    4369.69    4335.98    4349.33   18.736552
# 2017-08-17 21:30:00    4349.33    4369.69    4322.65    4354.35   13.210825
# 2017-08-17 21:45:00    4354.03    4368.68    4309.23    4333.55   19.269546
# 2017-08-17 22:00:00    4333.55    4349.63    4322.39    4334.32   11.280595
# ...                        ...        ...        ...        ...         ...
# 2025-11-12 20:30:00  101717.30  101846.15  101621.08  101683.41  173.974830
# 2025-11-12 20:45:00  101683.41  101716.61  101487.81  101539.01  114.583150
# 2025-11-12 21:00:00  101539.01  101897.99  101520.41  101894.32   95.287950
# 2025-11-12 21:15:00  101894.32  101894.33  101694.00  101715.78   87.972500
# 2025-11-12 21:30:00  101715.78  101864.54  101715.66  101864.31   79.703270
#
# ...

# %%
create_target_column(df_1y)
create_target_column(df_5y)
create_target_column(df_10y)
# Out:
#                           open       high        low      close      volume  \
# timestamp
# 2017-08-17 21:00:00    4346.74    4367.93    4315.85    4367.93   10.556113
# 2017-08-17 21:15:00    4346.73    4369.69    4335.98    4349.33   18.736552
# 2017-08-17 21:30:00    4349.33    4369.69    4322.65    4354.35   13.210825
# 2017-08-17 21:45:00    4354.03    4368.68    4309.23    4333.55   19.269546
# 2017-08-17 22:00:00    4333.55    4349.63    4322.39    4334.32   11.280595
# ...                        ...        ...        ...        ...         ...
# 2025-11-12 20:30:00  101717.30  101846.15  101621.08  101683.41  173.974830
# 2025-11-12 20:45:00  101683.41  101716.61  101487.81  101539.01  114.583150
# 2025-11-12 21:00:00  101539.01  101897.99  101520.41  101894.32   95.287950
# 2025-11-12 21:15:00  101894.32  101894.33  101694.00  101715.78   87.972500
# 2025-11-12 21:30:00  101715.78  101864.54  101715.66  101864.31   79.703270
#
# ...

# %%
df_1y['target'].value_counts()
# Out:
# target
#  0    23010
#  1     6265
# -1     5917
# Name: count, dtype: int64

# %%
export_df_1y = df_1y
export_df_5y = df_5y
export_df_10y = df_10y

# %store export_df_1y
# %store export_df_5y
# %store export_df_10y
# Out:
# Stored 'export_df_1y' (DataFrame)
# Stored 'export_df_5y' (DataFrame)
# Stored 'export_df_10y' (DataFrame)

# %%
df_10y.tail(n=100)
# Out:
#                           open       high        low      close     volume  \
# timestamp
# 2025-11-11 20:45:00  102829.77  102909.23  102658.36  102809.27  214.61049
# 2025-11-11 21:00:00  102809.27  103090.69  102659.17  102967.65  194.59036
# 2025-11-11 21:15:00  102967.65  103059.85  102769.23  102784.78   98.68881
# 2025-11-11 21:30:00  102784.78  102784.78  102476.09  102561.54  238.25717
# 2025-11-11 21:45:00  102561.55  102836.20  102479.75  102633.92  265.41141
# ...                        ...        ...        ...        ...        ...
# 2025-11-12 20:30:00  101717.30  101846.15  101621.08  101683.41  173.97483
# 2025-11-12 20:45:00  101683.41  101716.61  101487.81  101539.01  114.58315
# 2025-11-12 21:00:00  101539.01  101897.99  101520.41  101894.32   95.28795
# 2025-11-12 21:15:00  101894.32  101894.33  101694.00  101715.78   87.97250
# 2025-11-12 21:30:00  101715.78  101864.54  101715.66  101864.31   79.70327
#
# ...
